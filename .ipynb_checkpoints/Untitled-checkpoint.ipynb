# %%
from keras.models import load_model

model=load_model('tumorr.keras')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\ops\operation.py:208, in Operation.from_config(cls, config)
#     207 try:
# --> 208     return cls(**config)
#     209 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\conv2d.py:107, in Conv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#      87 def __init__(
#      88     self,
#      89     filters,
#    (...)
#     105     **kwargs
#     106 ):
# --> 107     super().__init__(
#     108         rank=2,
#     109         filters=filters,
# ...
